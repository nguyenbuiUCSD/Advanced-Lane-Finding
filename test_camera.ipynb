# %%
from camera import Camera
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# %%
cam = Camera("camera1")
if cam.is_calibrated == False:
    cam.calibrate_and_draw("camera_cal/", 9, 6)
# Out:
# Initializing camera ...
# Camera has not been calibrated yet ...
# Done ...
# Finding corners ...
# Done ...
# Calibrating Camera ...
# Camera configuration has been written to camera_config/camera1.conf
# Done ...
# Showing random sample
